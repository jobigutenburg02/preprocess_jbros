# %%
import preprocess_jbros as ps

# %%
ps.word_count('this is some text')
# Out:
# 4

# %%
ps.char_count('this is some text')
# Out:
# 14

# %%
ps.avg_word_len('this is some text')
# Out:
# 3.5

# %%
ps.stop_words_count('this is some text')
# Out:
# 3

# %%
ps.hashtags_count('this is some #text')
# Out:
# 1

# %%
ps.mentions_count('this is some @text')
# Out:
# 1

# %%
ps.numerics_count('this is some @text 123')
# Out:
# 1

# %%
ps.upper_case_count('this is some TEXT')
# Out:
# 1

# %%
ps.count_retweets('this is RT @some text')
# Out:
# 1

# %%
ps.remove_retweets('this is RT @some text')
# Out:
# 'this is  text'

# %%
ps.remove_html_tags('<p>this is RT @some text</p>')
# Out:
# 'this is RT @some text'

# %%
ps.remove_special_chars('this is RT @some text')
# Out:
# 'this is RT some text'

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/12.8 MB 1.5 MB/s eta 0:00:08
#      ---- ----------------------------------- 1.3/12.8 MB 1.6 MB/s eta 0:00:08
#      ----- ---------------------------------- 1.8/12.8 MB 1.8 MB/s eta 0:00:07
#      ------ --------------------------------- 2.1/12.8 MB 1.8 MB/s eta 0:00:06
#      -------- ------------------------------- 2.6/12.8 MB 1.9 MB/s eta 0:00:06
#      ---------- ----------------------------- 3.4/12.8 MB 2.1 MB/s eta 0:00:05
#      ------------ --------------------------- 3.9/12.8 MB 2.1 MB/s eta 0:00:05
#      -------------- ------------------------- 4.7/12.8 MB 2.3 MB/s eta 0:00:04
#      ---------------- ----------------------- 5.2/12.8 MB 2.3 MB/s eta 0:00:04
# ...

# %%
x = "The cats are playing with dogs"
ps.lemmatize(x)
# Out:
# 'the cat be play with dog'

# %%
x = "The cats are playin with dgs"
ps.correct_spelling(x)
# Out:
# 'The cats are plain with dogs'

# %%
x = "Awesome juice at rainy season is very good"
ps.get_noun_phrase(x)
# Out:
# WordList(['awesome', 'rainy season'])

# %%
x = "The cats are playing with dogs"
ps.translate(x, dest='ar')
# Out:
# 'القطط تلعب مع الكلاب'

# %%
ps.translate(x, dest='ml')
# Out:
# 'പൂച്ചകൾ നായ്ക്കളുമായി കളിക്കുന്നു'
